# %%
import warnings

warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

from google.cloud import bigquery
from google.oauth2 import service_account



# Consulta de ejemplo
query = """
select DISTINCT *
from tbsg.public_maestra_recurso 
where recurso_despacho is not null
"""

# Ejecutar la consulta
query_job = client.query(query).to_dataframe()

# %%
query_job
# Out:
#       id recurso_oferta recurso_despacho   recurso_ofei recurso_lp  \
# 0    134    MENORES_COL     LAFRISOLERA1    LAFRISOLERA       MHIX
# 1    430    MENORES_COL      LAFRISOLERA    LAFRISOLERA       MHIX
# 2    210    MENORES_COL      M_MORROAZUL    M_MORROAZUL       MHIX
# 3    172    MENORES_COL         M_ELEDEN         ELEDEN       MHIX
# 4    432    MENORES_COL           MCAUYA          CAUYA       MHIX
# ..   ...            ...              ...            ...        ...
# 514  352       SOGAMOSO         SOGAMOSO       SOGAMOSO       SOG1
# 515  492       SOGAMOSO        SOGAMOSOP       SOGAMOSO       SOG1
# 516  362       TCENTRO1         TCENTRO1  TERMOCENTROCC       TRM1
# 517  361       TCENTRO1         TCENTRO1  TERMOCENTROCC       TRM1
# 518  360       TCENTRO1         TCENTRO1  TERMOCENTROCC       TRM1
#
#     unidad_despacho   unidad_ofei codsic_planta codsic_agente    subarea  ...  \
# 0      LAFRISOLERA1   LAFRISOLERA          2S78          GPYG        CQR  ...
# 1       LAFRISOLERA   LAFRISOLERA          2S78          GPYG        CQR  ...
# 2       M_MORROAZUL   M_MORROAZUL          2SI1          RENG        CQR  ...
# 3          M_ELEDEN        ELEDEN          2SW1          PRIG        CQR  ...
# 4            MCAUYA         CAUYA          3AQP          SFEG        CQR  ...
# ..              ...           ...           ...           ...        ...  ...
# 514       SOGAMOSO3     SOGAMOSO3          SOG1          ISGG  SANTANDER  ...
# 515        SOGAMOSO     SOGAMOSO1          SOGP          ISGG  SANTANDER  ...
# 516       TCENTRO_3  TERMOCENTRO3          TRM1          TCNG  SANTANDER  ...
# 517       TCENTRO_2  TERMOCENTRO2          TRM1          TCNG  SANTANDER  ...
# 518       TCENTRO_1  TERMOCENTRO1          TRM1          TCNG  SANTANDER  ...
#
#            tipo tipo_despacho id_agente id_recurso id_subarea  unidad_id  \
# 0    HIDRAULICA            ND       167         77         22        130
# 1    HIDRAULICA            ND       167         77         22        421
# 2    HIDRAULICA            ND       218         95         22        206
# 3    HIDRAULICA            ND        30        112         22        170
# 4    HIDRAULICA            ND       232        116         22        423
# ..          ...           ...       ...        ...        ...        ...
# 514  HIDRAULICA            DC       189        258         17        343
# 515  HIDRAULICA            DC       189        468         17        585
# 516     TERMICA            DC       189        264         17        351
# 517     TERMICA            DC       189        264         17        350
# 518     TERMICA            DC       189        264         17        349
#
#      id_combustible  id_zona_seguridad     estado     recurso_ccomb
# 0                11               <NA>  OPERACIÓN  GEN. DISTRIBUIDA
# 1                11               <NA>  OPERACIÓN  GEN. DISTRIBUIDA
# 2                 2               <NA>  OPERACIÓN            NORMAL
# 3                11               <NA>  OPERACIÓN            NORMAL
# 4                11               <NA>  OPERACIÓN            NORMAL
# ..              ...                ...        ...               ...
# 514              11               <NA>  OPERACIÓN            NORMAL
# 515              11                511   INACTIVO            NORMAL
# 516               2               <NA>  OPERACIÓN   CICLO COMBINADO
# 517               2               <NA>  OPERACIÓN   CICLO COMBINADO
# 518               2               <NA>  OPERACIÓN   CICLO COMBINADO
#
# [519 rows x 23 columns]
