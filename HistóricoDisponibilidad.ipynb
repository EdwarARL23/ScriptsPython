# %% [markdown]
# ### Cálculo de la disponiblidad histórica de las plantas

# %%
# import warnings

# warnings.filterwarnings('ignore')
# warnings.simplefilter('ignore')

from pydataxm import *                           #Se realiza la importación de las librerias necesarias para ejecutar                        
from pydataxm.pydataxm import ReadDB as apiXM 
import datetime as dt                            
import pandas as pd
from pathlib import Path
import os

import json
import datetime as dt
from ftplib import FTP_TLS
import tkinter as tk
from tkinter import messagebox
import csv
from openpyxl import load_workbook

root = tk.Tk()
root.withdraw()
root.attributes("-topmost", True)  # ✅ Hace que los messagebox estén en primer plano
# Out:
# ''

# %%
def readfileOfe(file_path):
    # Read all lines from the file
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()
        
    # Initialize variables
    data = []
    current_agent = None

    # Process each line
    for line in lines:
        line = line.strip()

        if not line:
            continue  # Skip empty lines

        if line.startswith("AGENTE:"):
            current_agent = line.replace("AGENTE:", "").strip()
            continue

        parts = [x.strip() for x in line.split(",")]

        if len(parts) >= 3:
            # print(line)
            unidad = parts[0]
            tipo = parts[1]
            valores = parts[2:]

            if unidad=='URRA' and tipo=='AGCP':
                stop=1
             

            # Try to convert values to float; skip line if fails
            if len(valores)>6:
                valores_float = [float(v) if str(v).replace('.', '', 1).isdigit() else 0 for v in valores]
            else:
                if valores[0].replace('.', '', 1).isdigit():
                    valores_float = [float(v) for v in valores]
                else:
                    valores_float = [v for v in valores]
                

            for hora, valor in enumerate(valores_float, start=1):
                data.append({
                    "Agente": current_agent,
                    "Unidad": unidad,
                    "Tipo": tipo,
                    "Hora": hora,
                    "Valor": valor
                })

    # Convert to DataFrame
    df = pd.DataFrame(data)

    return df

# %%
def DispUni(df):
    # Lectura de datos con los mapeos
    s_parentpath=Path('C:\Alejo\cops\Data')
    filepath=s_parentpath.joinpath(s_parentpath,'Mapeos.xlsx')

    df=df[(df['Tipo']=='D')]

    df_precios_plt=pd.DataFrame()

    # --- Preprocesar df como diccionario para búsqueda rápida
    df_lookup = df.set_index(['Unidad', 'Hora'])['Valor'].to_dict()
    unidades_validas = set(df['Unidad'].unique())

    df_plt = df[['Unidad']]
    df_plt = df_plt.drop_duplicates(subset=['Unidad']).reset_index(drop=True)

    # Inicializar columnas D_1 a D_24
    l_per=[]
    for i in range(1, 25):
        df_plt[f'{i}'] = 0
        l_per.append(f'{i}')

    # Llenar valores por unidad y hora
    for ind, row in df_plt.iterrows():
        unidad = row['Unidad']

        if unidad in unidades_validas:
            for hora in range(1, 25):
                valor = df_lookup.get((unidad, hora), None)
                if valor is not None:
                    df_plt.at[ind, f'{hora}'] = valor
        else:
            print(f'No se encontró la unidad: {unidad}')

    # Concatenar resultados
    df_precios_plt = pd.concat([df_precios_plt, df_plt], axis=0, ignore_index=True)
    
    # df_plt_uni = pd.read_excel(filepath, sheet_name='Planta_Unidad')
    # df_precios_plt=df_precios_plt.merge(df_plt_uni,left_on=['Unidad'],right_on=['UniOfe'],how='Left')[l_col]
    
        
    return df_precios_plt

# %%
# Función para descargar el archivo
def DownFile(fecha_dt,UsuXM,PwsXM,Tipo):

    # # Connect to the FTP server (replace with your actual details)
    # ftps  = FTP_TLS()
    # ftps .connect('xmftps.xm.com.co', 210)  # default port is 210

    # # Secure the control connection
    # ftps .auth()
    # ftps .prot_p()  # Switch to secure data connection (important!)

    # ftps .login(UsuXM, PwsXM)

    # Obtener mes y día de la fecha inicial
    # Transformar string en fecha
    # fecha = dt.datetime.strptime(fecha_dt, "%d/%m/%Y")

    # Obtener mes y día
    year= fecha_dt.year
    mes = fecha_dt.month
    dia = fecha_dt.day

    # if Tipo=='Oferta':
    #     # Navigate to the directory you want to access
    #     ftps.cwd(rf"/INFORMACION_XM/PUBLICO/OFERTAS/INICIAL/{year:04d}-{mes:02d}")
    # else:
    #     messagebox.showinfo('Estado del proceso',f'No se reconoce el formato {Tipo}', parent=root)
    #     df=pd.DataFrame()
    #     return df


    # List files
    # files = ftps.nlst()
    # print("Available files:", files)


    if Tipo=='Oferta':
        # Download condiciones iniciales de planta
        pathfile=rf"C:\Información XM\PUBLICO\OFERTAS\INICIAL\{year:04d}-{mes:02d}"
        if not os.path.exists(pathfile):
            os.makedirs(pathfile)
        filename = rf"OFEI{mes:02d}{dia:02d}.TXT"

    # try:
    #     print(pathfile + "\\" + filename)
    #     with open(pathfile + "\\" + filename, 'wb') as f:
    #         ftps.retrbinary(f"RETR {filename}", f.write)

        # ftps.quit()
        # print(f"{filename} downloaded successfully.")
        print(pathfile + "\\" + filename)
        if Tipo=='Oferta':
            df=readfileOfe(pathfile + "\\" + filename)


    # except:
        # df=pd.DataFrame()

    
    return df

# %%
# # Función para descargar el archivo
# def DownFile(fecha_dt,UsuXM,PwsXM,Tipo):

#     # Connect to the FTP server (replace with your actual details)
#     ftps  = FTP_TLS()
#     ftps .connect('xmftps.xm.com.co', 210)  # default port is 210

#     # Secure the control connection
#     ftps .auth()
#     ftps .prot_p()  # Switch to secure data connection (important!)

#     ftps .login(UsuXM, PwsXM)

#     # Obtener mes y día de la fecha inicial
#     # Transformar string en fecha
#     # fecha = dt.datetime.strptime(fecha_dt, "%d/%m/%Y")

#     # Obtener mes y día
#     year= fecha_dt.year
#     mes = fecha_dt.month
#     dia = fecha_dt.day

#     if Tipo=='Oferta':
#         # Navigate to the directory you want to access
#         ftps.cwd(rf"/INFORMACION_XM/PUBLICO/OFERTAS/INICIAL/{year:04d}-{mes:02d}")
#     else:
#         messagebox.showinfo('Estado del proceso',f'No se reconoce el formato {Tipo}', parent=root)
#         df=pd.DataFrame()
#         return df


#     # List files
#     files = ftps.nlst()
#     # print("Available files:", files)


#     if Tipo=='Oferta':
#         # Download condiciones iniciales de planta
#         pathfile=rf"C:\Información XM\PUBLICO\OFERTAS\INICIAL\{year:04d}-{mes:02d}"
#         if not os.path.exists(pathfile):
#             os.makedirs(pathfile)
#         filename = rf"OFEI{mes:02d}{dia:02d}.TXT"

#     try:
#         print(pathfile + "\\" + filename)
#         with open(pathfile + "\\" + filename, 'wb') as f:
#             ftps.retrbinary(f"RETR {filename}", f.write)

#         ftps.quit()
#         # print(f"{filename} downloaded successfully.")

#         if Tipo=='Oferta':
#             df=readfileOfe(pathfile + "\\" + filename)


#     except:
#         df=pd.DataFrame()

    
#     return df

# %%
# Obtener la fecha del día 1
# FechaIni=dt.date(2022,1,1)
# FechaFin=dt.date(2022,1,2)
FechaIni=dt.date(2023,1,1)
FechaFin=dt.date(2025,9,30)
# FechaFin=dt.date(2023,12,31)
# FechaFin=dt.date(2022,7,11)
fecha_dt = FechaIni
UsuXM='1060588666'
PwsXM='Alejo230708*+'

df_data=pd.DataFrame()

while fecha_dt<=FechaFin:

    df_Ini=DownFile(fecha_dt,UsuXM,PwsXM,Tipo='Oferta')

    # Obtener disponibilidad por unidad
    df_DispPlt=DispUni(df_Ini)

    # Filtar por las unidades requeridas
    df_DispPlt=df_DispPlt[(df_DispPlt['Unidad'].isin(['FLORES2','FLORES3','FLORES4','FLORES1GAS','FLORES1VAPOR','GUAJIRA1','GUAJIRA2','PROELECTRICA1','PROELECTRICA2','TERMOCANDELARIACC1'
                                                   ,'TERMOCANDELARIACC2','TERMOCANDELARIACC3','TEBSA11','TEBSA12','TEBSA13','TEBSA14','TEBSA21','TEBSA22','TEBSA24','BARRANQUILLA3'
                                                   ,'BARRANQUILLA4']))]

    df_DispPlt['Fecha']=fecha_dt
    df_data=pd.concat([df_data,df_DispPlt],axis=0)

    fecha_dt=fecha_dt + dt.timedelta(days=1)
# Out:
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0101.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0102.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0103.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0104.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0105.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0106.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0107.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0108.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0109.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0110.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0111.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0112.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0113.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0114.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0115.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0116.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0117.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0118.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0119.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0120.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0121.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0122.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0123.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0124.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0125.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0126.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0127.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0128.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0129.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0130.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-01\OFEI0131.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0201.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0202.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0203.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0204.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0205.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0206.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0207.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0208.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0209.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0210.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0211.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0212.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0213.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0214.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0215.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0216.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0217.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0218.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0219.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0220.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0221.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0222.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0223.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0224.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0225.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0226.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0227.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-02\OFEI0228.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0301.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0302.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0303.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0304.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0305.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0306.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0307.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0308.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0309.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0310.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0311.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0312.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0313.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0314.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0315.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0316.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0317.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0318.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0319.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0320.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0321.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0322.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0323.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0324.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0325.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0326.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0327.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0328.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0329.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0330.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-03\OFEI0331.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0401.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0402.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0403.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0404.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0405.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0406.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0407.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0408.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0409.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0410.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0411.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0412.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0413.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0414.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0415.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0416.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0417.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0418.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0419.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0420.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0421.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0422.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0423.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0424.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0425.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0426.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0427.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0428.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0429.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-04\OFEI0430.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0501.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0502.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0503.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0504.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0505.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0506.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0507.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0508.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0509.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0510.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0511.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0512.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0513.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0514.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0515.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0516.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0517.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0518.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0519.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0520.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0521.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0522.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0523.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0524.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0525.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0526.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0527.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0528.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0529.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0530.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-05\OFEI0531.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0601.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0602.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0603.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0604.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0605.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0606.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0607.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0608.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0609.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0610.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0611.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0612.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0613.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0614.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0615.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0616.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0617.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0618.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0619.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0620.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0621.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0622.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0623.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0624.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0625.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0626.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0627.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0628.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0629.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-06\OFEI0630.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0701.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0702.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0703.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0704.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0705.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0706.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0707.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0708.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0709.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0710.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0711.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0712.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0713.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0714.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0715.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0716.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0717.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0718.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0719.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0720.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0721.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0722.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0723.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0724.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0725.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0726.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0727.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0728.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0729.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0730.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-07\OFEI0731.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0801.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0802.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0803.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0804.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0805.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0806.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0807.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0808.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0809.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0810.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0811.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0812.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0813.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0814.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0815.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0816.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0817.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0818.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0819.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0820.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0821.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0822.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0823.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0824.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0825.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0826.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0827.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0828.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0829.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0830.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-08\OFEI0831.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0901.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0902.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0903.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0904.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0905.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0906.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0907.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0908.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0909.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0910.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0911.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0912.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0913.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0914.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0915.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0916.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0917.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0918.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0919.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0920.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0921.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0922.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0923.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0924.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0925.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0926.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0927.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0928.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0929.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-09\OFEI0930.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1001.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1002.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1003.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1004.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1005.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1006.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1007.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1008.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1009.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1010.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1011.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1012.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1013.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1014.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1015.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1016.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1017.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1018.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1019.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1020.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1021.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1022.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1023.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1024.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1025.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1026.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1027.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1028.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1029.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1030.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-10\OFEI1031.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1101.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1102.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1103.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1104.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1105.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1106.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1107.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1108.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1109.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1110.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1111.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1112.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1113.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1114.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1115.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1116.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1117.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1118.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1119.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1120.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1121.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1122.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1123.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1124.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1125.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1126.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1127.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1128.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1129.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-11\OFEI1130.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1201.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1202.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1203.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1204.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1205.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1206.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1207.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1208.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1209.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1210.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1211.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1212.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1213.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1214.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1215.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1216.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1217.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1218.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1219.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1220.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1221.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1222.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1223.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1224.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1225.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1226.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1227.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1228.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1229.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1230.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2023-12\OFEI1231.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0101.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0102.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0103.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0104.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0105.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0106.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0107.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0108.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0109.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0110.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0111.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0112.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0113.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0114.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0115.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0116.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0117.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0118.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0119.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0120.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0121.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0122.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0123.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0124.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0125.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0126.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0127.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0128.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0129.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0130.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-01\OFEI0131.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0201.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0202.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0203.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0204.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0205.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0206.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0207.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0208.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0209.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0210.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0211.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0212.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0213.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0214.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0215.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0216.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0217.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0218.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0219.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0220.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0221.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0222.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0223.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0224.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0225.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0226.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0227.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0228.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-02\OFEI0229.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0301.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0302.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0303.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0304.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0305.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0306.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0307.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0308.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0309.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0310.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0311.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0312.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0313.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0314.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0315.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0316.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0317.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0318.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0319.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0320.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0321.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0322.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0323.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0324.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0325.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0326.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0327.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0328.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0329.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0330.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-03\OFEI0331.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0401.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0402.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0403.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0404.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0405.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0406.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0407.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0408.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0409.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0410.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0411.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0412.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0413.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0414.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0415.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0416.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0417.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0418.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0419.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0420.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0421.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0422.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0423.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0424.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0425.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0426.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0427.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0428.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0429.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-04\OFEI0430.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0501.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0502.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0503.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0504.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0505.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0506.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0507.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0508.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0509.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0510.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0511.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0512.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0513.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0514.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0515.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0516.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0517.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0518.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0519.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0520.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0521.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0522.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0523.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0524.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0525.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0526.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0527.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0528.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0529.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0530.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-05\OFEI0531.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0601.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0602.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0603.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0604.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0605.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0606.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0607.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0608.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0609.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0610.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0611.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0612.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0613.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0614.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0615.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0616.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0617.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0618.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0619.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0620.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0621.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0622.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0623.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0624.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0625.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0626.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0627.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0628.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0629.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-06\OFEI0630.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0701.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0702.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0703.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0704.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0705.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0706.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0707.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0708.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0709.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0710.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0711.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0712.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0713.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0714.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0715.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0716.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0717.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0718.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0719.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0720.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0721.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0722.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0723.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0724.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0725.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0726.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0727.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0728.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0729.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0730.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-07\OFEI0731.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0801.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0802.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0803.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0804.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0805.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0806.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0807.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0808.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0809.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0810.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0811.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0812.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0813.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0814.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0815.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0816.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0817.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0818.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0819.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0820.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0821.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0822.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0823.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0824.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0825.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0826.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0827.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0828.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0829.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0830.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-08\OFEI0831.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0901.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0902.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0903.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0904.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0905.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0906.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0907.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0908.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0909.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0910.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0911.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0912.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0913.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0914.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0915.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0916.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0917.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0918.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0919.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0920.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0921.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0922.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0923.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0924.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0925.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0926.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0927.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0928.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0929.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-09\OFEI0930.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1001.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1002.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1003.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1004.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1005.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1006.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1007.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1008.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1009.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1010.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1011.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1012.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1013.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1014.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1015.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1016.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1017.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1018.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1019.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1020.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1021.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1022.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1023.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1024.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1025.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1026.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1027.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1028.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1029.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1030.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-10\OFEI1031.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1101.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1102.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1103.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1104.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1105.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1106.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1107.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1108.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1109.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1110.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1111.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1112.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1113.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1114.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1115.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1116.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1117.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1118.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1119.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1120.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1121.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1122.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1123.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1124.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1125.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1126.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1127.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1128.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1129.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-11\OFEI1130.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1201.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1202.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1203.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1204.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1205.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1206.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1207.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1208.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1209.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1210.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1211.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1212.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1213.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1214.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1215.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1216.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1217.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1218.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1219.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1220.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1221.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1222.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1223.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1224.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1225.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1226.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1227.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1228.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1229.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1230.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2024-12\OFEI1231.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0101.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0102.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0103.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0104.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0105.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0106.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0107.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0108.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0109.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0110.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0111.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0112.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0113.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0114.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0115.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0116.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0117.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0118.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0119.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0120.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0121.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0122.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0123.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0124.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0125.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0126.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0127.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0128.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0129.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0130.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-01\OFEI0131.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0201.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0202.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0203.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0204.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0205.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0206.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0207.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0208.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0209.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0210.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0211.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0212.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0213.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0214.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0215.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0216.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0217.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0218.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0219.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0220.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0221.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0222.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0223.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0224.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0225.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0226.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0227.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-02\OFEI0228.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0301.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0302.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0303.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0304.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0305.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0306.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0307.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0308.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0309.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0310.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0311.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0312.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0313.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0314.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0315.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0316.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0317.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0318.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0319.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0320.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0321.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0322.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0323.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0324.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0325.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0326.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0327.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0328.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0329.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0330.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-03\OFEI0331.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0401.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0402.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0403.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0404.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0405.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0406.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0407.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0408.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0409.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0410.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0411.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0412.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0413.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0414.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0415.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0416.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0417.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0418.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0419.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0420.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0421.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0422.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0423.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0424.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0425.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0426.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0427.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0428.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0429.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-04\OFEI0430.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0501.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0502.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0503.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0504.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0505.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0506.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0507.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0508.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0509.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0510.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0511.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0512.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0513.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0514.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0515.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0516.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0517.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0518.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0519.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0520.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0521.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0522.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0523.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0524.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0525.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0526.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0527.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0528.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0529.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0530.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-05\OFEI0531.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0601.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0602.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0603.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0604.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0605.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0606.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0607.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0608.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0609.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0610.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0611.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0612.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0613.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0614.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0615.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0616.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0617.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0618.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0619.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0620.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0621.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0622.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0623.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0624.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0625.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0626.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0627.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0628.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0629.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-06\OFEI0630.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0701.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0702.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0703.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0704.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0705.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0706.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0707.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0708.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0709.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0710.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0711.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0712.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0713.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0714.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0715.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0716.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0717.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0718.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0719.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0720.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0721.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0722.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0723.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0724.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0725.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0726.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0727.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0728.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0729.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0730.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-07\OFEI0731.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0801.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0802.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0803.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0804.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0805.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0806.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0807.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0808.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0809.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0810.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0811.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0812.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0813.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0814.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0815.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0816.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0817.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0818.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0819.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0820.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0821.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0822.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0823.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0824.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0825.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0826.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0827.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0828.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0829.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0830.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-08\OFEI0831.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0901.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0902.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0903.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0904.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0905.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0906.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0907.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0908.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0909.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0910.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0911.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0912.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0913.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0914.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0915.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0916.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0917.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0918.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0919.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0920.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0921.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0922.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0923.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0924.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0925.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0926.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0927.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0928.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0929.TXT
# C:\Información XM\PUBLICO\OFERTAS\INICIAL\2025-09\OFEI0930.TXT

# %%
df_data.to_csv('DisponibildadHistorica.csv')

# %%
# Lectura de datos con los mapeos
# s_parentpath=Path(rf'C:\Alejo\Eje de Planeación\Análisis Energético\Ejecuciones 30 días\2025-10\Proyeccion_LP_27_31')
s_parentpath=Path(rf'C:\Alejo\Eje de Planeación\Análisis Energético\Ejecuciones 30 días\2025-11\ProyeccionLP_2032_2036')
filepath=s_parentpath.joinpath(s_parentpath,'DisponibildadHistorica.xlsx')

df_pltt_Ini = pd.read_excel(filepath, sheet_name='DispUni')

# %%
df_pltt=df_pltt_Ini.copy()
df_pltt['flag'] = df_pltt.loc[:, 1:24].apply(lambda row: 0 if (row == 0).any() else 1, axis=1)
df_pltt=df_pltt[['Fecha','Unidad','flag']]
df_pltt
# Out:
#            Fecha              Unidad  flag
# 0     2022-01-01            GUAJIRA1     0
# 1     2022-01-01            GUAJIRA2     1
# 2     2022-01-01       PROELECTRICA1     1
# 3     2022-01-01       PROELECTRICA2     0
# 4     2022-01-01             TEBSA11     1
# ...          ...                 ...   ...
# 26262 2025-09-30             TEBSA22     1
# 26263 2025-09-30             TEBSA24     0
# 26264 2025-09-30  TERMOCANDELARIACC1     1
# 26265 2025-09-30  TERMOCANDELARIACC2     1
# 26266 2025-09-30  TERMOCANDELARIACC3     1
#
# [26267 rows x 3 columns]

# %% [markdown]
# #### Código para concurrencia de unidades

# %%
import pandas as pd
import numpy as np
from collections import defaultdict, deque

# =========================================================
# PARÁMETROS GLOBALES
# =========================================================
FUTURO_INI = pd.Timestamp('2026-01-01')   # horizonte futuro: inicio
FUTURO_FIN = pd.Timestamp('2026-12-31')   # horizonte futuro: fin
RANDOM_SEED = 42                          # reproducibilidad
EPS = 1e-6                                # estabilidad numérica

# Control de concurrencia global (requisito 3)
PERC_CAP_HIST = 0.90     # percentil histórico para limitar K_t futuro por mes
MAX_SHIFT_DIAS = 3       # máximo corrimiento (± días) para redistribuir sin romper rachas
MAX_REASIGN_POR_DIA = 3  # cuántas rachas como máximo mover por día "congestivo"

rng = np.random.default_rng(RANDOM_SEED)


# =========================================================
# UTILIDADES BÁSICAS
# =========================================================
def prepara_historico(df: pd.DataFrame) -> pd.DataFrame:
    """
    Normaliza el histórico.
    Espera columnas: ['Fecha','Unidad','flag'] con flag ∈ {0,1} (1=disponible, 0=indisponible).
    """
    d = df.copy()
    d['Fecha'] = pd.to_datetime(d['Fecha'])
    d = d.sort_values(['Unidad','Fecha']).reset_index(drop=True)
    d['flag'] = d['flag'].astype(int).clip(0, 1)
    return d


def matriz_fuera_diaria(df: pd.DataFrame) -> pd.DataFrame:
    """
    Retorna una matriz diaria (index=Fecha, columnas=Unidad) con 0/1 indicando 'fuera'.
    """
    d = df.copy()
    d['fuera'] = 1 - d['flag']
    mat = d.pivot_table(index='Fecha', columns='Unidad', values='fuera', aggfunc='mean', fill_value=0)
    return (mat > 0.5).astype(int)


# =========================================================
# (1) PERSISTENCIA TIPO MARKOV POR UNIDAD Y MES
# =========================================================
def estima_transiciones_markov(df: pd.DataFrame) -> pd.DataFrame:
    """
    Estima, por unidad y mes, probabilidades de transición:
      p01 = P(fuera_t=1 | fuera_{t-1}=0, mes),
      p10 = P(fuera_t=0 | fuera_{t-1}=1, mes),
      pi1 = fracción histórica de días fuera (margen mensual).
    Retorna DataFrame ['Unidad','mes','p01','p10','pi1'].
    """
    d = df.copy()
    d = d.sort_values(['Unidad','Fecha'])
    d['mes'] = d['Fecha'].dt.month
    d['fuera'] = 1 - d['flag']
    d['fuera_prev'] = d.groupby('Unidad')['fuera'].shift()

    grupos = d.dropna(subset=['fuera_prev']).groupby(['Unidad','mes'])
    n00 = grupos.apply(lambda g: ((g['fuera_prev']==0) & (g['fuera']==0)).sum()).rename('n00')
    n01 = grupos.apply(lambda g: ((g['fuera_prev']==0) & (g['fuera']==1)).sum()).rename('n01')
    n10 = grupos.apply(lambda g: ((g['fuera_prev']==1) & (g['fuera']==0)).sum()).rename('n10')
    n11 = grupos.apply(lambda g: ((g['fuera_prev']==1) & (g['fuera']==1)).sum()).rename('n11')
    cnt  = pd.concat([n00, n01, n10, n11], axis=1).reset_index().fillna(0)

    # Suavizado bayesiano leve para evitar 0/1 puros
    cnt['p01'] = (cnt['n01'] + 0.5) / (cnt['n00'] + cnt['n01'] + 1.0)
    cnt['p10'] = (cnt['n10'] + 0.5) / (cnt['n10'] + cnt['n11'] + 1.0)

    # Margen pi1 mensual
    marg = d.groupby(['Unidad','mes'])['fuera'].mean().rename('pi1').reset_index()

    trans = cnt.merge(marg, on=['Unidad','mes'], how='outer').fillna(0.0)
    trans['p01'] = trans['p01'].clip(0.001, 0.999)
    trans['p10'] = trans['p10'].clip(0.001, 0.999)
    trans['pi1'] = trans['pi1'].clip(0.0, 1.0)
    return trans


# =========================================================
# (2) DETECCIÓN DE ALTA CONCURRENCIA (≥ 80%) Y CLUSTERIZACIÓN
# =========================================================
def pares_concurrencia_fuerte(df: pd.DataFrame, umbral: float = 0.80):
    """
    Detecta pares de unidades con concurrencia histórica 'alta'.
    Métrica usada: condicional simétrica alta:
        c_ij = min( P(j=1 | i=1), P(i=1 | j=1) )
    (Equivalente a exigir que, cuando una cae, la otra también cae con prob ≥ umbral.)
    Retorna lista de pares [(u1,u2), ...].
    """
    mat = matriz_fuera_diaria(df)  # Fecha x Unidad (0/1)
    U = mat.columns.tolist()

    pares = []
    # Precalcular tasas y co-ocurrencias
    tot = len(mat)
    sum_u = mat.sum(axis=0)  # días fuera por unidad
    for i in range(len(U)):
        ui = U[i]
        xi = mat[ui].values
        di = int(sum_u[ui])
        if di == 0:
            continue
        for j in range(i+1, len(U)):
            uj = U[j]
            xj = mat[uj].values
            dj = int(sum_u[uj])
            if dj == 0:
                continue
            both = int((xi & xj).sum())
            p_j_g_i = both / (di + EPS)
            p_i_g_j = both / (dj + EPS)
            c_ij = min(p_j_g_i, p_i_g_j)
            if c_ij >= umbral:
                pares.append((ui, uj))
    return pares


def clusters_desde_pares(pares):
    """
    Construye clústeres (componentes conexos) a partir de pares con alta concurrencia.
    Retorna lista de clusters: [set(unidades), ...].
    Unidades no conectadas quedan en clusters unitarios luego (más abajo).
    """
    # Grafo no dirigido
    adj = defaultdict(set)
    for a,b in pares:
        adj[a].add(b)
        adj[b].add(a)

    vistos = set()
    clusters = []

    for nodo in list(adj.keys()):
        if nodo in vistos: 
            continue
        # BFS/DFS
        comp = set()
        dq = deque([nodo])
        vistos.add(nodo)
        while dq:
            v = dq.popleft()
            comp.add(v)
            for w in adj[v]:
                if w not in vistos:
                    vistos.add(w)
                    dq.append(w)
        clusters.append(comp)

    return clusters


def clusters_fortificados(df: pd.DataFrame, umbral: float = 0.80):
    """
    Produce clusters de alta concurrencia (≥ umbral).
    Además, agrega como clusters unitarios a las unidades no incluidas.
    """
    mat = matriz_fuera_diaria(df)
    U = set(mat.columns.tolist())
    pares = pares_concurrencia_fuerte(df, umbral=umbral)
    base = clusters_desde_pares(pares)
    usados = set().union(*base) if base else set()
    # Añadir unidades solitarias
    for u in U - usados:
        base.append({u})
    return base


# =========================================================
# (3) SIMULACIÓN FUTURA CON PERSISTENCIA Y CLUSTERS FORZADOS
# =========================================================
def simula_markov_clusters(df: pd.DataFrame,
                           clusters: list[set],
                           trans: pd.DataFrame,
                           ini: pd.Timestamp,
                           fin: pd.Timestamp,
                           seed: int = 42) -> pd.DataFrame:
    """
    Simula futuro día a día con:
      - Persistencia por unidad (Markov mensual) para clusters unitarios.
      - Persistencia compartida por cluster (cadena común) para clusters de tamaño >1,
        forzando concurrencia (todas 'fuera' juntas).
    Estrategia de cluster (>1):
      - Se construye una cadena común por mes:
          p01_cluster = promedio de p01 de sus miembros (mes),
          p10_cluster = promedio de p10 de sus miembros (mes),
          pi1_cluster = promedio de pi1 de sus miembros (mes).
      - Se simula estado_cl(m) y se asigna a TODAS las unidades del cluster.
    Retorna DataFrame ['fecha','unidad','fuera'].
    """
    rng_local = np.random.default_rng(seed)
    dias = pd.date_range(ini, fin, freq='D')
    unidades_all = sorted(df['Unidad'].unique().tolist())

    # Mapas (Unidad, mes) -> parámetros Markov
    key = list(zip(trans['Unidad'], trans['mes']))
    map_p01 = {k: v for k, v in zip(key, trans['p01'])}
    map_p10 = {k: v for k, v in zip(key, trans['p10'])}
    map_pi1 = {k: v for k, v in zip(key, trans['pi1'])}

    # Prepara salida
    registros = []

    # Helper para simular cadena binaria con p01/p10 mensuales
    def simula_cadena(m, estado_prev, p01, p10):
        if estado_prev == 0:
            return 1 if rng_local.random() < p01 else 0
        else:
            return 0 if rng_local.random() < p10 else 1

    # Simulación cluster por cluster
    # Para clusters unitarios, se simula por unidad.
    # Para clusters >1, se simula una cadena común y se aplica a todos.
    # Estado inicial: se muestrea según pi1 del mes inicial.

    for cluster in clusters:
        cluster = sorted(list(cluster))
        if len(cluster) == 1:
            # --- CLUSTER UNITARIO: Markov individual ---
            u = cluster[0]
            estado_u = None
            for f in dias:
                m = f.month
                pi1 = map_pi1.get((u, m), 0.0)
                p01 = map_p01.get((u, m), 0.02)
                p10 = map_p10.get((u, m), 0.20)

                if estado_u is None:
                    estado_u = 1 if rng_local.random() < pi1 else 0
                else:
                    estado_u = simula_cadena(m, estado_u, p01, p10)

                if estado_u == 1:
                    registros.append({'fecha': f, 'unidad': u, 'fuera': 1})

        else:
            # --- CLUSTER >1: Markov común (fuerza concurrencia) ---
            # Parámetros cluster por mes = promedio de miembros
            # (robusto y suficiente para mantener persistencia)
            # Estado común:
            estado_c = None
            for f in dias:
                m = f.month
                # promedios
                p01_vals = [map_p01.get((u, m), 0.02) for u in cluster]
                p10_vals = [map_p10.get((u, m), 0.20) for u in cluster]
                pi1_vals = [map_pi1.get((u, m), 0.00) for u in cluster]

                p01_c = float(np.mean(p01_vals))
                p10_c = float(np.mean(p10_vals))
                pi1_c = float(np.mean(pi1_vals))

                if estado_c is None:
                    estado_c = 1 if rng_local.random() < pi1_c else 0
                else:
                    estado_c = 1 if simula_cadena(m, estado_c, p01_c, p10_c) == 1 else 0

                if estado_c == 1:
                    for u in cluster:
                        registros.append({'fecha': f, 'unidad': u, 'fuera': 1})

    return pd.DataFrame(registros)


# =========================================================
# (4) CONTROL DE CONCURRENCIA GLOBAL (RESTRICCIÓN SUAVE)
# =========================================================
def pmf_concurrencia_historica_por_mes(df: pd.DataFrame) -> pd.DataFrame:
    """
    PMF de concurrencia histórica por mes. Útil para fijar caps y diagnóstico.
    Retorna DataFrame ['mes','unidades_fuera','prob'] y también devuelve caps recomendados.
    """
    d = df.copy()
    d['fuera'] = 1 - d['flag']
    K = d.groupby('Fecha')['fuera'].sum().rename('K').reset_index()
    K['mes'] = K['Fecha'].dt.month
    pmf = K.groupby('mes')['K'].value_counts(normalize=True).rename('prob').reset_index()
    return pmf


def cap_concurrencia_por_mes_desde_hist(df: pd.DataFrame, perc: float = 0.90) -> dict:
    """
    Calcula un 'cap' mensual de concurrencia diaria K_t a partir del percentil histórico.
    Retorna dict: mes -> K_cap.
    """
    d = df.copy()
    d['fuera'] = 1 - d['flag']
    K = d.groupby('Fecha')['fuera'].sum().rename('K').reset_index()
    K['mes'] = K['Fecha'].dt.month
    Kcaps = {}
    for m, g in K.groupby('mes'):
        Kcaps[m] = int(np.ceil(g['K'].quantile(perc)))
    return Kcaps


def redistribuye_para_cap(df_fuera: pd.DataFrame,
                          Kcap_mes: dict,
                          max_shift: int = 3,
                          max_mover_por_dia: int = 3) -> pd.DataFrame:
    """
    Aplica una redistribución suave para que K_t futuro no exceda caps mensuales.
    Mantiene rachas (mueve bloques completos) hasta ±max_shift días dentro del mismo mes.
    Prioriza mover rachas más cortas primero (menos impacto).
    """
    if df_fuera.empty:
        return df_fuera

    # 1) Compactar a intervalos por unidad para manipular rachas
    df = df_fuera[['fecha','unidad']].copy()
    df = df.sort_values(['unidad','fecha']).reset_index(drop=True)
    df['g'] = df.groupby('unidad')['fecha'].apply(lambda s: (s.diff().dt.days.ne(1)).cumsum()).reset_index(level=0, drop=True)

    bloques = (
        df.groupby(['unidad','g'])
          .agg(fechaIni=('fecha','min'), fechaFin=('fecha','max'), dur=('fecha','count'))
          .reset_index()
    )

    # Mapa de concurrencia diaria actual
    K = df_fuera.groupby('fecha')['unidad'].nunique().rename('K').to_frame()
    fechas_all = pd.date_range(df_fuera['fecha'].min(), df_fuera['fecha'].max(), freq='D')
    K = K.reindex(fechas_all).fillna(0).astype(int)
    K['mes'] = K.index.to_series().dt.month

    # Ordenar bloques (cortos primero)
    bloques = bloques.sort_values('dur').reset_index(drop=True)

    # Función auxiliar para probar mover un bloque a un nuevo inicio
    def puede_mover(unidad, ini_old, fin_old, ini_new):
        dur = (fin_old - ini_old).days + 1
        fin_new = ini_new + pd.Timedelta(days=dur-1)
        # mismo mes
        if ini_new.month != ini_old.month or fin_new.month != fin_old.month:
            return False, None, None
        # chequear cap
        rango = pd.date_range(ini_new, fin_new, freq='D')
        for f in rango:
            if (K.loc[f, 'K'] + 1) > Kcap_mes.get(f.month, 999):
                return False, None, None
        return True, ini_new, fin_new

    # Intentar aliviar días que exceden cap
    excedidos = K[K['K'] > K['mes'].map(Kcap_mes)].index.tolist()
    # Iterar días excedidos; por cada día, mover hasta 'max_mover_por_dia' bloques
    for f in excedidos:
        movidos = 0
        if movidos >= max_mover_por_dia:
            continue

        # Buscar bloques que cubran f (candidatos)
        cand = bloques[(bloques['fechaIni'] <= f) & (bloques['fechaFin'] >= f)]
        # Ordenar candidatos por dur ascendente
        cand = cand.sort_values('dur')

        for _, row in cand.iterrows():
            if movidos >= max_mover_por_dia:
                break
            u, ini, fin, dur = row['unidad'], row['fechaIni'], row['fechaFin'], row['dur']

            # Probar corrimientos -max_shift..+max_shift excepto 0
            ok = False
            for delta in list(range(1, max_shift + 1)) + list(range(-1, -max_shift - 1, -1)):
                ini_new = ini + pd.Timedelta(days=delta)
                puede, a, b = puede_mover(u, ini, fin, ini_new)
                if puede:
                    # Actualizar concurrencia diaria: liberar días viejos y ocupar nuevos
                    for ff in pd.date_range(ini, fin, freq='D'):
                        K.loc[ff, 'K'] = max(0, K.loc[ff, 'K'] - 1)
                    for ff in pd.date_range(a, b, freq='D'):
                        K.loc[ff, 'K'] = K.loc[ff, 'K'] + 1

                    # Actualizar bloque en DataFrame 'bloques' usando su índice real
                    idx_row = row.name
                    bloques.at[idx_row, 'fechaIni'] = a
                    bloques.at[idx_row, 'fechaFin'] = b

                    ok = True
                    movidos += 1
                    break  # salir del ciclo delta si se movió
            # si logramos mover alguno, seguimos al siguiente candidato

    # Reconstruir df_fuera a partir de bloques reubicados
    registros = []
    for _, r in bloques.iterrows():
        for f in pd.date_range(r['fechaIni'], r['fechaFin'], freq='D'):
            registros.append({'fecha': f, 'unidad': r['unidad'], 'fuera': 1})

    df_new = pd.DataFrame(registros)
    return df_new


# =========================================================
# (5) COMPACTACIÓN Y DIAGNÓSTICO
# =========================================================
def compacta_intervalos(df_fuera: pd.DataFrame) -> pd.DataFrame:
    """
    Compacta días consecutivos por unidad en intervalos [fechaIni, fechaFin].
    Salida: ['unidad','fechaIni','fechaFin','Pini','Pfin'] con 1–24.
    """
    if df_fuera.empty:
        return pd.DataFrame(columns=['unidad','fechaIni','fechaFin','Pini','Pfin'])

    d = df_fuera.sort_values(['unidad','fecha']).reset_index(drop=True)
    d['g'] = d.groupby('unidad')['fecha'].apply(lambda s: (s.diff().dt.days.ne(1)).cumsum()).reset_index(level=0, drop=True)

    res = (
        d.groupby(['unidad','g'], as_index=False)
         .agg(fechaIni=('fecha','min'), fechaFin=('fecha','max'))
    )
    res['Pini'] = 1
    res['Pfin'] = 24
    return res[['unidad','fechaIni','fechaFin','Pini','Pfin']].sort_values(['unidad','fechaIni']).reset_index(drop=True)


def diagnostico_concurrencia(df_fuera: pd.DataFrame):
    """
    Concurrencia futura diaria y PMFs (para control/calibración).
    """
    conc = (
        df_fuera.groupby('fecha')['unidad']
                .nunique()
                .rename('unidades_fuera')
                .reset_index()
    )
    conc['mes'] = conc['fecha'].dt.month
    pmf_mes_fut = (
        conc.groupby('mes')['unidades_fuera']
            .value_counts(normalize=True)
            .rename('prob')
            .reset_index()
    )
    pmf_global_fut = (
        conc['unidades_fuera']
            .value_counts(normalize=True)
            .rename_axis('unidades_fuera')
            .reset_index(name='prob')
    )
    return conc, pmf_mes_fut, pmf_global_fut


# =========================================================
# (6) ORQUESTADOR PRINCIPAL — CUMPLE TUS 3 REQUISITOS
# =========================================================
def plan_indisponibilidad_2027_2031(df: pd.DataFrame,
                                    umbral_concurrencia_fuerte: float = 0.80,
                                    aplicar_cap: bool = True) -> dict:
    """
    Pipeline completo que cumple:
    1) Rachas realistas (persistencia) por unidad (Markov mensual).
    2) Si concurrencia histórica entre unidades ≥ umbral (default 80%),
       se fuerzan como clúster que cae junto en la proyección (p.ej., ciclo combinado G/V).
    3) Control de concurrencia global: evita “muchas” indisponibilidades el mismo día
       comparado con histórico, con un cap por mes y redistribución suave de rachas.

    Returns:
      {
        'plan_intervals': DataFrame ['unidad','fechaIni','fechaFin','Pini','Pfin'],
        'concurrencia_diaria': DataFrame ['fecha','unidades_fuera','mes'],
        'pmf_mes_futura': DataFrame PMF mensual de concurrencia,
        'pmf_global_futura': DataFrame PMF global de concurrencia,
        'clusters': lista de sets (clústeres detectados),
        'Kcap_mes': dict (si aplicar_cap=True)
      }
    """
    # --- Preparación histórica ---
    df_hist = prepara_historico(df)

    # --- Persistencia por unidad (Markov mensual) ---
    trans = estima_transiciones_markov(df_hist)

    # --- Clusters de concurrencia fuerte (≥80%) ---
    clusters = clusters_fortificados(df_hist, umbral=umbral_concurrencia_fuerte)

    # --- Simulación futura con clusters y persistencia ---
    df_fuera = simula_markov_clusters(df_hist, clusters, trans, FUTURO_INI, FUTURO_FIN, seed=RANDOM_SEED)
    # df_fuera: ['fecha','unidad','fuera'=1]

    # --- Control de concurrencia global (cap mensual + redistribución suave) ---
    Kcap_mes = {}
    if aplicar_cap:
        Kcap_mes = cap_concurrencia_por_mes_desde_hist(df_hist, perc=PERC_CAP_HIST)
        df_fuera = redistribuye_para_cap(df_fuera, Kcap_mes, max_shift=MAX_SHIFT_DIAS, max_mover_por_dia=MAX_REASIGN_POR_DIA)

    # --- Salida final compactada para optimización ---
    plan_intervals = compacta_intervalos(df_fuera)

    # --- Diagnóstico de concurrencia generada ---
    conc_fut, pmf_mes_fut, pmf_global_fut = diagnostico_concurrencia(df_fuera)

    return {
        'plan_intervals': plan_intervals,
        'concurrencia_diaria': conc_fut,
        'pmf_mes_futura': pmf_mes_fut,
        'pmf_global_futura': pmf_global_fut,
        'clusters': clusters,
        'Kcap_mes': Kcap_mes
    }

# %%
# =========================================================
# USO EJEMPLO:
# =========================================================
resultados = plan_indisponibilidad_2027_2031(df_pltt)  # df con ['Fecha','Unidad','flag']
plan = resultados['plan_intervals']
print(plan.head())
print("Clusters detectados:", resultados['clusters'])
print("Caps por mes:", resultados['Kcap_mes'])
# Out:
#           unidad   fechaIni   fechaFin  Pini  Pfin
# 0  BARRANQUILLA3 2032-04-23 2032-04-24     1    24
# 1  BARRANQUILLA3 2032-12-05 2032-12-05     1    24
# 2  BARRANQUILLA3 2033-04-04 2033-04-04     1    24
# 3  BARRANQUILLA3 2033-04-20 2033-04-20     1    24
# 4  BARRANQUILLA3 2033-08-05 2033-08-06     1    24
# Clusters detectados: [{'FLORES1GAS', 'FLORES1VAPOR'}, {'FLORES4', 'FLORES3'}, {'FLORES2'}, {'TEBSA22'}, {'TERMOCANDELARIACC1'}, {'PROELECTRICA1'}, {'TEBSA24'}, {'TEBSA11'}, {'GUAJIRA2'}, {'BARRANQUILLA3'}, {'TEBSA21'}, {'GUAJIRA1'}, {'TEBSA12'}, {'PROELECTRICA2'}, {'TERMOCANDELARIACC2'}, {'TERMOCANDELARIACC3'}, {'BARRANQUILLA4'}, {'TEBSA14'}, {'TEBSA13'}]
# Caps por mes: {1: 2, 2: 3, 3: 2, 4: 3, 5: 4, 6: 4, 7: 3, 8: 5, 9: 5, 10: 5, 11: 5, 12: 1}

# %%
plan.to_csv('Indisponibilidad.csv')
