# %%
import requests
import json
url = "https://www.simem.co/backend-files/api/PublicData?startdate=2024-09-25&enddate=2024-09-25&datasetId=31356e"
response = requests.get(url)
print(json.loads(response.content))
# Out:
# {'parameters': {'idDataset': '31356e', 'startDate': '2024-09-25', 'endDate': '2024-09-25', 'columnDestinyName': None, 'values': []}, 'success': True, 'result': {'idDataset': '31356e', 'name': 'Parámetros técnicos de las plantas de generación Hidráulicas', 'metadata': {'description': 'Contiene la información de agente Operador, Capacidad efectiva neta CEN, tecnología de generación, Fecha de Puesta en Operación Comercial FPO e información de retiro de las plantas hidraúlicas que se encuentran en operación comercial.', 'creationDate': '2023-09-30 11:43:45', 'lastUpdate': '2024-11-21 11:16:54', 'nextUpdateDate': '2024-11-22 11:00:00', 'entity': 'XM', 'category': 'Parámetros técnicos de las plantas de generación Hidráulicas', 'periodicity': 'Diaria', 'granularity': 'Diaria', 'historicData': 'https://paratec.xm.com.co/paratec/SitePages/Default.aspx', 'private': False}, 'filterDate': 'Fecha', 'records': [{'Fecha': '2024-09-25', 'CodigoDuracion': 'P1D', 'FechaPublicacion': '2024-09-25', 'Cod
# ...

# %%
import pandas as pd
date=pd.DataFrame(json.loads(response.content))
date
# Out:
#                    parameters  success  \
# idDataset              31356e     True
# startDate          2024-09-25     True
# endDate            2024-09-25     True
# columnDestinyName        None     True
# values                     []     True
# name                      NaN     True
# metadata                  NaN     True
# filterDate                NaN     True
# records                   NaN     True
# variables                 NaN     True
# columns                   NaN     True
# tags                      NaN     True
#
#                                                               result
# idDataset                                                     31356e
# startDate                                                        NaN
# endDate                                                          NaN
# columnDestinyName                                                NaN
# values                                                           NaN
# ...
