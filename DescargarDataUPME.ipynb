# %% [markdown]
# ### Descargar información de los proyectos de generación de la UPME

# %%
import pandas as pd

# Pega aquí tu URL publicada (la que estás viendo en el navegador)
pubhtml_url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vRo2gEfSdDhd6KJvgbLSuRLZHLToT2KUtDORgI--6C6wjW6Qw04QyT1-2aLW7_r7HadVWoNWMfnMk1j/pubhtml?gid=850949900&single=true"

# Convertimos pubhtml -> output=csv (truco típico en publicaciones)
csv_url = pubhtml_url.replace("/pubhtml", "/pub").split("?")[0] + "?gid=850949900&single=true&output=csv"

df = pd.read_csv(csv_url)

df.to_excel("creg_075_ca.xlsx", index=False)
print("Listo: creg_075_ca.xlsx")
# Out:
# Listo: creg_075_ca.xlsx
