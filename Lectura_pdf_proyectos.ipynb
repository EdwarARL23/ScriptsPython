# %%
# Lectura de librerías
import pdfplumber
import pandas as pd
import os

# %%
# Ruta donde están los PDFs
carpeta_pdfs = rf'C:\Alejo\PreciosBolsaEnersinc\Informacion_20250716\UPME'
archivos_pdf = [f for f in os.listdir(carpeta_pdfs) if f.endswith('.pdf')]

# Lista para guardar todas las tablas
df_data = pd.DataFrame()

l_col=['Nombre del Proyecto','Descripción','Empresa','Capacidad(MW)','Tipo / Recurso','OEF','CLPE-02-2019'
       ,'Garantía','Punto de Conexión','Expansión / Condición','FPO','Informe_Auditoria','Estado','archivo_origen','pagina_origen']

for archivo in archivos_pdf:
    ruta_pdf = os.path.join(carpeta_pdfs, archivo)
    print(f"Procesando: {archivo}")

    with pdfplumber.open(ruta_pdf) as pdf:
        for i, pagina in enumerate(pdf.pages):
            try:
                tablas = pagina.extract_tables()
                for tabla in tablas:
                    if tabla and len(tabla) > 1:  # Verifica que no esté vacía
                        df = pd.DataFrame(tabla[1:], columns=tabla[0])  # Usa primera fila como encabezado
                        df['archivo_origen'] = archivo
                        df['pagina_origen'] = i + 1

                        # renombrar los nombres de las columnas de acuerdo con el número
                        df.columns = [f'col_{i+1}' for i in range(df.shape[1])]

                        # Detectar si la columna 1 tiene Nomvre de proyecto
                        if df['col_1'].astype(str).str.contains('Nombre del Proyecto').any():

                            for col in df.columns:
                                missing_ratio = df[col].isna().mean()
                                if missing_ratio > 0.8:
                                    df.drop(columns=col, inplace=True)

                            # Elimiar la fila que tenga Nombre del proyecto en la columna col_1
                            df = df[df['col_1'] != 'Nombre del Proyecto']

                            # Eliminar filas donde más del 50% de las columnas sean missing values o estén vacío
                            df = df[df.isnull().mean(axis=1) <= 0.2]

                            # Cambiar los nombre de las columnas por los de l_col
                            df.columns = l_col[:df.shape[1]]

                            # Elimiar filas donde la columna Nombre del proyecto y la columna Estado estén vacías
                            df = df[~(df['Nombre del Proyecto'].isna() | df['Nombre del Proyecto'].eq('')) & ~(df['Estado'].isna() | df['Estado'].eq(''))]


                            # Concatnenar las tablas
                            df_data=pd.concat([df_data,df],axis=0)

            except Exception as e:
                print(f"Error en página {i+1} de {archivo}: {e}")
# Out:
# Procesando: Informe_avance_proyectos_generacion_Abril_2024.pdf
# Procesando: Informe_Avance_proyectos_Generacion_Diciembre2020.pdf
# Procesando: Informe_Avance_proyectos_Generacion_Diciembre2021.pdf
# Error en página 9 de Informe_Avance_proyectos_Generacion_Diciembre2021.pdf: Length mismatch: Expected axis has 17 elements, new values have 15 elements
# Procesando: Informe_Avance_proyectos_Generacion_Diciembre_2022.pdf
# Procesando: Informe_avance_proyectos_generacion_Diciembre_2023.pdf
# Procesando: Informe_avance_proyectos_generacion_Diciembre_2024.pdf
# Procesando: Informe_Avance_proyectos_Generacion_Julio2022.pdf
# Procesando: Informe_Avance_proyectos_Generacion_Julio_2023.pdf
# Procesando: Informe_avance_proyectos_generacion_Julio_2024.pdf
# Procesando: Informe_Avance_proyectos_Generacion_Junio2021.pdf
# Error en página 9 de Informe_Avance_proyectos_Generacion_Junio2021.pdf: Length mismatch: Expected axis has 16 elements, new values have 15 elements
# Procesando: Informe_Avance_proyectos_Generacion_Marzo2021.pdf
# Procesando: Informe_Avance_proyectos_Generacion_Marzo2022.pdf
# Procesando: Informe_Avance_proyectos_Generacion_Marzo_2023.pdf
# Procesando: Informe_Avance_proyectos_Generacion_Octubre_2023.pdf
# Procesando: Informe_avance_proyectos_generacion_Octubre_2024.pdf
# Procesando: Informe_Avance_proyectos_Generacion_Septiembre2021.pdf
# Error en página 9 de Informe_Avance_proyectos_Generacion_Septiembre2021.pdf: Length mismatch: Expected axis has 17 elements, new values have 15 elements
# Procesando: Informe_Avance_proyectos_Generacion_Septiembre2022.pdf

# %%
df_data.to_csv('Información proyectos.csv', index=False, encoding='utf-8-sig')

# df_data.to_csv('Información proyectos.csv')

# %%
import re
import unicodedata


PALABRAS_COMUNES = {
    "proyecto", "parque", "solar", "fotovoltaico", "eólico", "hidroeléctrico", 
    "de", "del", "la", "el", "central", "planta", "generación", "energia","eolico", "autog", "agpe"
}

def normalizar_nombre(nombre):
    if not isinstance(nombre, str):
        return ""
    # Elimina tildes
    nombre = unicodedata.normalize('NFKD', nombre).encode('ascii', 'ignore').decode('utf-8')
    # Minúsculas
    nombre = nombre.lower()
    # Quita puntuación y símbolos
    nombre = re.sub(r'[^\w\s]', '', nombre)
    # Quita palabras comunes
    palabras = nombre.split()
    palabras_filtradas = [p for p in palabras if p not in PALABRAS_COMUNES]
    return " ".join(palabras_filtradas)

# %%
# from thefuzz import process
from fuzzywuzzy import fuzz, process

# --- Paso 2: función de fuzzy join ---
def fuzzy_left_join(df_izq, col_izq, df_der, col_der, umbral=85):
    # Limpieza de nombres
    df_izq["nombre_limpio"] = df_izq[col_izq].apply(normalizar_nombre)
    df_der["nombre_limpio"] = df_der[col_der].apply(normalizar_nombre)

    # Lista de referencia (derecha)
    nombres_ref = df_der["nombre_limpio"].tolist()

    # Buscar mejor match para cada fila del DF izquierdo
    matches = df_izq["nombre_limpio"].apply(
        lambda x: process.extractOne(x, nombres_ref,scorer=fuzz.ratio) if x else (None, 0)
    )

    # Crear columnas de match y score
    df_izq["match_nombre"] = matches.apply(lambda x: x[0])
    df_izq["similitud"] = matches.apply(lambda x: x[1])

    # Filtrar solo coincidencias aceptables
    df_match = df_izq[df_izq["similitud"] >= umbral].copy()

    # Hacer el join con los datos del DataFrame derecho
    df_final = pd.merge(
        df_match,
        df_der,
        left_on="match_nombre",
        right_on="nombre_limpio",
        suffixes=("_izq", "_der"),
        how="left"
    )

    return df_final

# %% [markdown]
# ### Obtener información de las hojas

# %%
import pandas as pd

# %%
# Leer archivo de UPME
df_upme = pd.read_csv(rf'C:\Alejo\PreciosBolsaEnersinc\Informacion_20250716\Información_UPME.csv', header=0, encoding='utf-8-sig')
df_upme=df_upme[(df_upme['Tipo'].isin(['Eólico','Solar']))]

# %%
proyectos_unicos = df_upme['Nombre del Proyecto'].unique()
df_proyectos = pd.DataFrame()

for proyecto in proyectos_unicos:
    df_filtrado = df_upme[df_upme['Nombre del Proyecto'] == proyecto]
    df_filtrado = df_filtrado[df_filtrado['FPO'].notna() & (df_filtrado['FPO'] != '')]
    registro = {
        'Proyecto': proyecto,
        'FPO_Ini': df_filtrado['FPO'].min(),
        # 'FPO_max': df_filtrado['FPO'].max(),
        'CEN': df_filtrado['CEN'].iloc[0],
        'Despacho': df_filtrado['Despacho'].iloc[0],
        'Tipo': df_filtrado['Tipo'].iloc[0],
        'OEF': df_filtrado['OEF'].iloc[0]
    }
        
    df_proyectos = pd.concat([df_proyectos, pd.DataFrame([registro])], ignore_index=True)

    df_proyectos.fillna(0, inplace=True)

# %%
df_proyectos["nombre_normalizado"] = df_proyectos["Proyecto"].apply(normalizar_nombre)
df_proyectos
# Out:
#                                           Proyecto     FPO_Ini    CEN  \
# 0                                        WINDPESHI  2022-03-31    200
# 1                                     TOLIMA NORTE  2025-12-31     50
# 2                                    SOLAR EL PASO  2023-11-30     70
# 3                                       SHANGRI LA  2025-12-31    160
# 4                                       SAN FELIPE  2020-12-31     90
# 5                                     PV BARZALOSA  2026-03-31    100
# 6       PROYECTO PARQUE SOLAR VILLAVIEJA DE 200 MW  2026-11-15    200
# 7                         PLANTA SOLAR LA ORQUÍDEA  2026-11-12    200
# 8                               PARUQE EÓLICO BETA  2026-11-01    280
# 9                       PARQUE SOLAR PUERTA DE ORO  2025-12-31    300
# 10                               PARQUE SOLAR URRÁ  2025-07-31  21.83
# 11                            PARQUE SOLAR SAHAGÚN  2024-12-31    400
# 12                         PARQUE SOLAR MATIMBA II  2025-12-31     99
# 13                       PARQUE SOLAR LAS PALMERAS  2026-07-31    200
# 14                         PARQUE SOLAR LAS MARIAS  2027-11-30   99.5
# 15                        PARQUE SOLAR LA VIRGINIA  2025-12-31     80
# 16                            PARQUE SOLAR GUAYEPO  2024-12-01    400
# 17            PARQUE SOLAR FOTOVOLTAICO PV LA MATA  2024-04-08     80
# 18            PARQUE SOLAR FOTOVOLTAICO VALLEDUPAR  2026-12-31    100
# 19              PARQUE SOLAR FOTOVOLTAICO TAMARINO  2027-12-31    200
# 20                 PARQUE SOLAR FOTOVOLTAICO MISAK  2026-12-31     80
# 21      PARQUE SOLAR FOTOVOLTAICO MELGAR DE 180 MW  2025-12-31    180
# 22         PARQUE SOLAR FOTOVOLTAICO FLOREO 200 MW  2026-12-31    200
# 23             PARQUE SOLAR FOTOVOLTAICO CIMITARRA  2027-05-31    200
# 24                         PARQUE SOLAR EL CAMPANO  2025-12-31    100
# 25                          PARQUE SOLAR EL COROZO  2027-12-31    250
# 26                              PARQUE SOLAR CHINÚ  2027-05-31    350
# 27              PARQUE FOTOVOLTAICO SUNNORTE 35 MW  2024-11-30     35
# 28                   PARQUE FOTOVOLTAICO LA PALOMA  2025-11-30     40
# 29                               PARQUE EÓLICO JK2  2023-07-31     75
# 30                               PARQUE EÓLICO JK1  2023-07-31    180
# 31                              PARQUE EÓLICO BETA  2026-11-30    280
# 32                             PARQUE EÓLICO ALPHA  2026-11-30    212
# 33                                         LA LOMA  2021-05-31    150
# 34                                KUISA (TUMAWIND)  2023-07-31    200
# 35                                         IRRAIPA  2023-07-31     99
# 36                                         IPAPURE  2023-07-31    201
# 37                                     GUAYEPO III  2026-10-06    200
# 38                                         GUAYEPO  2023-03-31    400
# 39            GENERACIÓN FOTOVOLTAICA LA PRIMAVERA  2024-12-31     57
# 40                                       FUNDACIÓN  2024-06-24     90
# 41                                   EL PASO SOLAR  2022-11-30     70
# 42                                      EL CAMPANO  2021-12-31     99
# 43                             CHEMESKY (URRAICHI)  2023-07-31    100
# 44  CENTRAL ELECTRICA DE BIOMASA VILLA-NUEVA 25 MW  2024-10-31    180
# 45                                         CARTAGO           -     99
# 46                                        CARRIZAL  2023-07-31    195
# 47                                        CAMELIAS  2023-11-30    250
# 48                 BOSQUES SOLARES DE LOS LLANOS 6  2025-12-31   79.6
# 49                                            BETA  2023-10-15    280
# 50                                       ATLÁNTICO  2026-10-13  119.5
# 51                                           ALPHA  2023-10-15    212
# 52                                        ACACIA 2  2021-12-31     80
#
#    Despacho    Tipo     OEF                  nombre_normalizado
# 0        DC  Eólico    0.78                           windpeshi
# 1        DC   Solar   0.096                        tolima norte
# 2        DC   Solar    0.24                                paso
# 3        DC   Solar    0.54                             shangri
# 4        DC   Solar       0                          san felipe
# 5        DC   Solar    0.21                        pv barzalosa
# 6        DC   Solar     0.4                   villavieja 200 mw
# 7        DC   Solar   0.334                            orquidea
# 8        DC  Eólico     0.2                         paruqe beta
# 9        DC   Solar     0.6                          puerta oro
# 10       DC   Solar   0.035                                urra
# 11       DC   Solar   0.071                             sahagun
# 12       DC   Solar     0.2                          matimba ii
# 13       DC   Solar    0.43                        las palmeras
# 14       DC   Solar    0.17                          las marias
# 15       DC   Solar    0.31                            virginia
# 16       DC   Solar     1.2                             guayepo
# 17       DC   Solar  0.2494                             pv mata
# 18       DC   Solar    0.35                          valledupar
# 19       DC   Solar    0.41                            tamarino
# 20       DC   Solar    0.15                               misak
# 21       DC   Solar    0.37                       melgar 180 mw
# 22       DC   Solar    0.43                       floreo 200 mw
# 23       DC   Solar    0.47                           cimitarra
# 24       DC   Solar    0.33                             campano
# 25       DC   Solar    0.54                              corozo
# 26       DC   Solar     0.6                               chinu
# 27       DC   Solar   0.081                      sunnorte 35 mw
# 28       DC   Solar   0.078                              paloma
# 29       DC  Eólico   0.445                                 jk2
# 30       DC  Eólico    0.89                                 jk1
# 31       DC  Eólico     0.2                                beta
# 32       DC  Eólico    0.15                               alpha
# 33       DC   Solar    0.52                                loma
# 34       DC  Eólico    0.28                      kuisa tumawind
# 35       DC  Eólico       0                             irraipa
# 36       DC  Eólico       0                             ipapure
# 37       DC   Solar   0.574                         guayepo iii
# 38       DC   Solar     1.2                             guayepo
# 39       DC   Solar    0.09   generacion fotovoltaica primavera
# 40       DC   Solar    0.17                           fundacion
# 41       DC   Solar    0.24                                paso
# 42       DC   Solar       -                             campano
# 43       DC  Eólico     0.2                   chemesky urraichi
# 44       DC  Eólico    0.89  electrica biomasa villanueva 25 mw
# 45       DC   Solar       0                             cartago
# 46       DC  Eólico       0                            carrizal
# 47       DC  Eólico       0                            camelias
# 48       DC   Solar    0.22        bosques solares los llanos 6
# 49       DC  Eólico     0.2                                beta
# 50       DC   Solar   0.552                           atlantico
# 51       DC  Eólico    0.15                               alpha
# 52       DC  Eólico   0.331                            acacia 2

# %%
import pandas as pd

# Ruta del archivo Excel
ruta_excel = r'C:\Alejo\PreciosBolsaEnersinc\Informacion_20250716\Seguimiento_radar_marzo_2024.xlsx'

# Leer todas las hojas del archivo
xls = pd.ExcelFile(ruta_excel)
hojas_filtradas = [hoja for hoja in xls.sheet_names if any(str(año) in hoja for año in range(2018, 2025))]

df_data_radar = pd.DataFrame()
# Recorrer cada hoja filtrada y leer su contenido
for hoja in hojas_filtradas:
    df_hoja = pd.read_excel(xls, sheet_name=hoja)
    df_hoja = df_hoja[['PROYECTO', 'FPO']]
    df_hoja = df_hoja.rename(columns={'FPO': 'FPO_Ini'})
    df_hoja = df_hoja[df_hoja['PROYECTO'].notna() & (df_hoja['PROYECTO'] != '')]
    df_hoja['origen']=hoja

    df_data_radar=pd.concat([df_data_radar,df_hoja],axis=0)

# %%
df_data_radar["nombre_normalizado"] = df_data_radar["PROYECTO"].apply(normalizar_nombre)
df_data_radar
# Out:
#            PROYECTO                                          FPO_Ini  \
# 0      Hidroituango                              2018-11-01 00:00:00
# 1           Ambeima  no tiene fecha probable de entrada en operación
# 2       Gecelca 3.2                              2018-04-30 00:00:00
# 4       Porvenir II                                             2023
# 5           La Luna                              2022-06-01 00:00:00
# ..              ...                                              ...
# 176     Chorreritas                                              NaN
# 177    PSF Mangales                                              NaN
# 178   El Roble 19.5                              2025-12-31 00:00:00
# 179  La Cayena 19.9                              2025-12-31 00:00:00
# 180        Caracolí                                       No reporta
#
#          origen nombre_normalizado
# 0    marzo 2018       hidroituango
# 1    marzo 2018            ambeima
# 2    marzo 2018         gecelca 32
# 4    marzo 2018        porvenir ii
# 5    marzo 2018               luna
# ..          ...                ...
# 176  marzo 2024        chorreritas
# 177  marzo 2024       psf mangales
# 178  marzo 2024          roble 195
# 179  marzo 2024         cayena 199
# 180  marzo 2024           caracoli
#
# [1964 rows x 4 columns]

# %%
from pydataxm import *                           #Se realiza la importación de las librerias necesarias para ejecutar                        
from pydataxm.pydataxm import ReadDB as apiXM 
import datetime as dt                            
import pandas as pd
from pathlib import Path
import os

# %%
FechaIni=dt.date(2025, 7, 1)
FechaFin=dt.date(2025, 7, 15)

df_Rec= apiXM.request_data(pydataxm.ReadDB(),    #Se indica el objeto que contiene el serivicio
                        "ListadoRecursos",                #Se indica el nombre de la métrica tal como se llama en el campo metricID
                        "Sistema",                 #Campo que indica si es Sistema, Agente, Recurso, Comercializador
                        FechaIni,       #Corresponde a la fecha inicial de la consulta
                        FechaFin)      #Corresponde a la fecha final de la consulta
# df_Rec=df_Rec.drop('Date',axis=1)

# %%
df_Rec1=df_Rec[['Values_Name','Values_Type','Values_Disp','Values_OperStartdate']]
df_Rec1=df_Rec1[(df_Rec1['Values_Type'].isin(['SOLAR','EOLICA']))]
df_Rec1.to_csv('OperacionRenovable.csv')
df_Rec1 = df_Rec1[~df_Rec1['Values_Name'].str.contains('FUTURA', case=False, na=False)]
df_Rec1["nombre_normalizado"] = df_Rec1["Values_Name"].apply(normalizar_nombre)
df_Rec1
# Out:
#                           Values_Name Values_Type                 Values_Disp  \
# 26           AUTOG CELSIA SOLAR YUMBO       SOLAR  NO DESPACHADO CENTRALMENTE
# 42               CELSIA SOLAR BOLIVAR       SOLAR  NO DESPACHADO CENTRALMENTE
# 48                      AGPE NAFERTEX       SOLAR  NO DESPACHADO CENTRALMENTE
# 50    AGPE TECNOEMPAQUES DE OCCIDENTE       SOLAR  NO DESPACHADO CENTRALMENTE
# 52         AGPE SFV MCDONALDS SOLEDAD       SOLAR  NO DESPACHADO CENTRALMENTE
# ...                               ...         ...                         ...
# 982                           GUAYEPO       SOLAR     DESPACHADO CENTRALMENTE
# 1000                          LA MATA       SOLAR     DESPACHADO CENTRALMENTE
# 1085               PARQUE SOLAR TEPUY       SOLAR     DESPACHADO CENTRALMENTE
# 1086                TRINA-VATIA BSLII       SOLAR  NO DESPACHADO CENTRALMENTE
# 1087               TRINA-VATIA BSLIII       SOLAR  NO DESPACHADO CENTRALMENTE
#
#      Values_OperStartdate       nombre_normalizado
# 26             2017-09-03             celsia yumbo
# 42             2019-02-03           celsia bolivar
# 48             2019-11-27                 nafertex
# 50             2019-12-19  tecnoempaques occidente
# 52             2020-02-27    sfv mcdonalds soledad
# ...                   ...                      ...
# 982            2024-11-30                  guayepo
# 1000           2024-06-27                     mata
# 1085           2024-06-12                    tepuy
# 1086           2021-01-22         trinavatia bslii
# 1087           2020-11-30        trinavatia bsliii
#
# [858 rows x 5 columns]

# %%
# Ejecutar el fuzzy join para las plantas que están en operación
df_Opera1 = fuzzy_left_join(df_Rec1, "Values_Name", df_proyectos, "Proyecto", umbral=95)[['Values_Name','Values_Type','Values_Disp','Values_OperStartdate','FPO_Ini']]
# df_Opera1 = fuzzy_left_join(df_Rec1, "Values_Name", df_proyectos, "Proyecto", umbral=95)

df_Opera2 = fuzzy_left_join(df_Rec1, "Values_Name", df_data_radar, "PROYECTO", umbral=95)[['Values_Name','Values_Type','Values_Disp','Values_OperStartdate','FPO_Ini']]
# df_Opera2 = fuzzy_left_join(df_Rec1, "Values_Name", df_data_radar, "PROYECTO", umbral=95)
# df_Opera2 = df_Opera2.rename(columns={'FPO': 'FPO_Ini'})

df_Opera=pd.concat([df_Opera1,df_Opera2],axis=0)

df_Opera2.to_csv('RecursosOperacion.csv')

# %%
df_Opera
# Out:
#                          Values_Name Values_Type                 Values_Disp  \
# 0    BOSQUES SOLARES DE LOS LLANOS 5       SOLAR  NO DESPACHADO CENTRALMENTE
# 1    BOSQUES SOLARES DE LOS LLANOS 4       SOLAR  NO DESPACHADO CENTRALMENTE
# 2                          FUNDACION       SOLAR     DESPACHADO CENTRALMENTE
# 3                         SHANGRI LA       SOLAR     DESPACHADO CENTRALMENTE
# 4                            EL PASO       SOLAR     DESPACHADO CENTRALMENTE
# ..                               ...         ...                         ...
# 154               PARQUE SOLAR TEPUY       SOLAR     DESPACHADO CENTRALMENTE
# 155               PARQUE SOLAR TEPUY       SOLAR     DESPACHADO CENTRALMENTE
# 156               PARQUE SOLAR TEPUY       SOLAR     DESPACHADO CENTRALMENTE
# 157               PARQUE SOLAR TEPUY       SOLAR     DESPACHADO CENTRALMENTE
# 158               PARQUE SOLAR TEPUY       SOLAR     DESPACHADO CENTRALMENTE
#
#     Values_OperStartdate              FPO_Ini
# 0             2022-09-12           2025-12-31
# 1             2022-09-12           2025-12-31
# 2             2024-06-24           2024-06-24
# 3             2025-02-28           2025-12-31
# 4             2024-03-23           2023-11-30
# ..                   ...                  ...
# 154           2024-06-12  2023-07-01 00:00:00
# 155           2024-06-12  2023-10-01 00:00:00
# 156           2024-06-12                  NaN
# 157           2024-06-12    Diciembre de 2023
# 158           2024-06-12    Diciembre de 2023
#
# [167 rows x 5 columns]

# %%
# Ruta del archivo Excel
ruta_excel = r'C:\Alejo\PreciosBolsaEnersinc\Informacion_20250716\ProyectosGen.xlsx'
df_hoja = pd.read_excel(ruta_excel, sheet_name='Export')
df_hoja=df_hoja[(df_hoja['Tipo'].isin(['Solar','Eólico']))]
df_hoja["nombre_normalizado"] = df_hoja["Proyecto"].apply(normalizar_nombre)

# %%
df_hoja
# Out:
#         Código                                 Proyecto  CEN [MW]        FPO  \
# 0    PROG00107                              Prosperidad     19.50 2025-12-20
# 2    PROG00356                                Windpeshi    200.00 2026-09-30
# 4    PROG00364  Atlántico Solar II Polo Nuevo de 9,9 MW      9.90 2025-12-30
# 6    PROG00396                                      JK3     45.00 2026-12-31
# 7    PROG00397                   Parque Eólico Tumawind    200.00 2026-12-31
# ..         ...                                      ...       ...        ...
# 401  PROG15810                             GD Polaris 2      0.99 2025-10-08
# 402  PROG15836                  GD EDQ Solar La Tebaida      0.12 2025-08-15
# 403  PROG15863                         GD ERCO Camilocé      0.99 2025-09-08
# 404  PROG15866                                 GD P15-4      0.99 2025-09-22
# 405  PROG15870                                 GD P15-1      0.99 2025-10-11
#
#        Tipo OEF     Área operativa     Tipo OEF  Fecha obligación  \
# 0     Solar  NO             Caribe          NaN               NaN
# 2    Eólico  NO             Caribe  Subasta CxC               NaN
# 4     Solar  NO             Caribe          NaN               NaN
# 6    Eólico  NO             Caribe          NaN               NaN
# 7    Eólico  NO             Caribe  Subasta CxC               NaN
# ..      ...  ..                ...          ...               ...
# 401   Solar  NO      Suroccidental          NaN               NaN
# 402   Solar  NO      Suroccidental          NaN               NaN
# 403   Solar  NO  Antioquía - Chocó          NaN               NaN
# 404   Solar  NO           Nordeste          NaN               NaN
# 405   Solar  NO           Nordeste          NaN               NaN
#
#     Subárea operativa                                    Promotor  \
# 0           Atlantico                 LA PROSPERIDAD SOLAR S.A.S.
# 2                 GCM                        ENEL COLOMBIA SA ESP
# 4           Atlantico       TECHNOELITE GREEN ENERGY S.A.S. E.S.P
# 6                 GCM           AES COLOMBIA & CIA. S.C.A. E.S.P.
# 7                 GCM                        ENEL COLOMBIA SA ESP
# ..                ...                                         ...
# 401      Cauca-Narino                      EVOLTI COMPANY SAS BIC
# 402               CQR  EMPRESA DE ENERGIA DEL QUINDIO S.A. E.S.P.
# 403         Antioquia                  ERCO GENERACION S.A.S. ESP
# 404         Santander               ES INVEST COLOMBIA S.A.S. ESP
# 405         Santander               ES INVEST COLOMBIA S.A.S. ESP
#
#               Puntos de Conexión Fecha de Puesta en Operación Oficial  \
# 0               Salamina 34.5 kV                  12/20/2025 00:00:00
# 2             Cuestecitas 220 kV                  09/30/2026 00:00:00
# 4                Baranoa 13.8 kV                  12/30/2023 00:00:00
# 6               Colectora 500 kV                  12/01/2026 00:00:00
# 7             Colectora 1 500 kV                  12/31/2026 00:00:00
# ..                           ...                                  ...
# 401            Remolinos 13.8 kV                                  NaN
# 402                          NaN                                  NaN
# 403                Amagá 13.2 kV                                  NaN
# 404  Puente Sogamoso 34.5/13.2kV                                  NaN
# 405  Puente Sogamoso 34.5/13.2kV                                  NaN
#
#                 nombre_normalizado
# 0                      prosperidad
# 2                        windpeshi
# 4    atlantico ii polo nuevo 99 mw
# 6                              jk3
# 7                         tumawind
# ..                             ...
# 401                   gd polaris 2
# 402                 gd edq tebaida
# 403               gd erco camiloce
# 404                        gd p154
# 405                        gd p151
#
# [354 rows x 14 columns]

# %%
# Ejecutar el fuzzy join para las plantas que están en proyecto
# df_Pro1 = fuzzy_left_join(df_hoja, "Proyecto", df_proyectos, "Proyecto", umbral=95)[['Proyecto_izq','CEN [MW]','FPO','Tipo_izq','OEF_izq','FPO_Ini']]
df_Pro1 = fuzzy_left_join(df_hoja, "Proyecto", df_proyectos, "Proyecto", umbral=90)
df_Pro1 = df_Pro1.rename(columns={'Proyecto_izq': 'Proyecto','Tipo_izq': 'Tipo','OEF_izq': 'OEF'})

df_Pro2 = fuzzy_left_join(df_hoja, "Proyecto", df_data_radar, "PROYECTO", umbral=95)[['Proyecto','CEN [MW]','FPO','Tipo','OEF','FPO_Ini']]


df_Pro=pd.concat([df_Pro1,df_Pro2],axis=0)

df_Pro1.to_csv('RecursosProyectos.csv')

# %%
df_hoja1=df_hoja.copy()
# Lista de referencia (derecha)
nombres_ref = df_proyectos["nombre_normalizado"].tolist()

# Buscar mejor match para cada fila del DF izquierdo
matches = df_hoja1["nombre_normalizado"].apply(
    lambda x: process.extractOne(x, nombres_ref) if x else (None, 0)
    )

df_hoja1['Resultado']=matches

df_hoja1=df_hoja1[['Proyecto','nombre_normalizado','Resultado']]

# %%
df_hoja1
# Out:
#                                     Proyecto             nombre_normalizado  \
# 0                                Prosperidad                    prosperidad
# 2                                  Windpeshi                      windpeshi
# 4    Atlántico Solar II Polo Nuevo de 9,9 MW  atlantico ii polo nuevo 99 mw
# 6                                        JK3                            jk3
# 7                     Parque Eólico Tumawind                       tumawind
# ..                                       ...                            ...
# 401                             GD Polaris 2                   gd polaris 2
# 402                  GD EDQ Solar La Tebaida                 gd edq tebaida
# 403                         GD ERCO Camilocé               gd erco camiloce
# 404                                 GD P15-4                        gd p154
# 405                                 GD P15-1                        gd p151
#
#                 Resultado
# 0        (puerta oro, 54)
# 2        (windpeshi, 100)
# 4         (atlantico, 90)
# 6               (jk2, 67)
# 7    (kuisa tumawind, 90)
# ..                    ...
# 401        (acacia 2, 86)
# 402        (orquidea, 49)
# 403        (camelias, 57)
# 404   (melgar 180 mw, 39)
# 405             (jk1, 45)
#
# [354 rows x 3 columns]

# %%
from fuzzywuzzy import fuzz, process
process.extractOne('atlantico ii polo nuevo 99 mw',nombres_ref,scorer=fuzz.ratio)
# Out:
# c:\Users\eramirez\AppData\Local\Programs\Python\Python311\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# ('atlantico', 47)
